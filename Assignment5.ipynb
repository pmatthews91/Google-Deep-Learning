# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5243, 3084, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[target]
      labels[i * num_skips + j, 0] = buffer[skip_window]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#     labels: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['anarchism', 'a', 'originated', 'term', 'of', 'term', 'originated', 'as']
#     labels: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.807356
# Nearest to s: queensberry, haredi, thoroughbreds, taunting, parsing, affect, hike, lyne,
# Nearest to called: chinatown, waged, shirow, underbelly, americo, phosphors, kabbalah, flaccus,
# Nearest to seven: script, mailing, refusal, sumner, tulip, taxpayers, casting, kneel,
# Nearest to it: rewrites, away, flock, p, semmelweis, sidemen, marina, lex,
# Nearest to such: flesh, inefficiencies, supermodel, karelian, restores, suras, voiceless, theorised,
# Nearest to but: byng, mal, barsoom, eaten, heiland, affect, vagina, depicting,
# Nearest to after: vox, pressuring, uscis, keystrokes, seanad, cruz, disloyalty, motives,
# Nearest to while: deputies, bath, domesticated, gunnar, indonesia, amaranth, chipsets, caligula,
# Nearest to many: einen, writable, seneca, infect, hippocampus, englishman, pronoun, platform,
# Nearest to this: studded, elwood, isin, resettled, lange, league, lethe, ssp,
# Nearest to an: romita, benetton, curia, lentils, juice, limestone, shoot, folds,
# Nearest to for: brill, reputation, harold, suprema, alphabets, enthusiasm, koffice, rebbe,
# Nearest to in: nitrates, elo, corrosion, tristram, puccini, connotation, mortals, dafoe,
# Nearest to between: emphasises, murdock, rovere, tonne, comet, fiji, stick, castor,
# Nearest to two: yersinia, hinges, pixar, teutoburg, decius, evasion, unmik, grabbing,
# Nearest to history: polygamous, debugger, guinevere, thread, guantanamo, efficacy, facts, condensates,
# Average loss at step 2000: 4.369227
# Average loss at step 4000: 3.866873
# Average loss at step 6000: 3.794936
# Average loss at step 8000: 3.686187
# Average loss at step 10000: 3.615102
# Nearest to s: his, and, or, forbidding, menstrual, miquelon, piercing, storehouse,
# Nearest to called: exploits, kibo, waged, very, restless, wushu, kabbalah, bizarre,
# Nearest to seven: six, eight, nine, five, three, four, zero, two,
# Nearest to it: he, this, there, that, still, not, they, also,
# Nearest to such: known, well, replicants, meteorologist, forged, volcanism, suras, prospectors,
# Nearest to but: symplectic, sonnets, turned, wrote, typically, dura, could, throbbing,
# Nearest to after: keystrokes, bent, ethically, sonnet, with, ns, prosperity, normandy,
# Nearest to while: austrian, nchen, bath, ribera, bradbury, deputies, appraisal, catalyzed,
# Nearest to many: these, einen, all, most, some, odes, recovery, lingering,
# Nearest to this: it, the, which, increased, a, their, wakshul, metasyntactic,
# Nearest to an: wakshul, nanotech, cordillera, shoot, procellariiformes, dougal, metasyntactic, lentils,
# Nearest to for: with, in, feb, through, ailment, steroids, amon, driscoll,
# Nearest to in: on, of, at, from, with, atlanteans, ns, lattimore,
# Nearest to between: nicolay, longer, pregnancy, tonne, figured, in, lose, gimme,
# Nearest to two: three, four, five, seven, six, eight, nine, one,
# Nearest to history: fes, rope, unsure, guantanamo, polygamous, stamping, polytheism, walloon,
# Average loss at step 12000: 3.608853
# Average loss at step 14000: 3.572084
# Average loss at step 16000: 3.412362
# Average loss at step 18000: 3.458477
# Average loss at step 20000: 3.540218
# Nearest to s: miquelon, residency, grid, routers, luddite, swaps, mega, weymouth,
# Nearest to called: exploits, kibo, hints, incorporation, graciously, continuous, prosciutto, kota,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to it: he, this, there, which, they, she, usually, that,
# Nearest to such: known, well, replicants, these, forged, linguistique, many, doses,
# Nearest to but: however, which, and, retriever, that, when, though, if,
# Nearest to after: keystrokes, bent, normandy, ascended, sonnet, undetectable, with, steiger,
# Nearest to while: but, when, guitars, chez, without, mingled, transplant, bradbury,
# Nearest to many: some, these, all, several, most, other, einen, the,
# Nearest to this: it, which, the, a, increased, his, fournier, metasyntactic,
# Nearest to an: the, nanotech, wakshul, shoot, cordillera, translated, flavour, folds,
# Nearest to for: with, of, by, through, to, picasso, in, herbrand,
# Nearest to in: at, with, on, under, vila, from, atlanteans, and,
# Nearest to between: nicolay, from, longer, pregnancy, against, airspeed, orbits, with,
# Nearest to two: three, five, six, four, seven, one, eight, zero,
# Nearest to history: fes, polytheism, rope, unsure, transl, parisians, chamberlain, walloon,
# Average loss at step 22000: 3.501150
# Average loss at step 24000: 3.491338
# Average loss at step 26000: 3.486597
# Average loss at step 28000: 3.479294
# Average loss at step 30000: 3.502711
# Nearest to s: his, whose, residency, victor, mega, tongs, coppersmith, corrode,
# Nearest to called: exploits, vaguely, continuous, graciously, kibo, prosciutto, soho, axon,
# Nearest to seven: six, five, eight, four, nine, three, zero, two,
# Nearest to it: he, there, this, she, which, they, not, who,
# Nearest to such: well, known, these, many, some, replicants, linguistique, fringed,
# Nearest to but: however, and, when, while, although, though, before, if,
# Nearest to after: before, during, when, from, snowman, bent, keystrokes, sonnet,
# Nearest to while: but, when, however, transplant, although, without, nage, hashshashin,
# Nearest to many: some, several, these, all, most, such, those, various,
# Nearest to this: which, it, that, what, he, some, the, any,
# Nearest to an: wakshul, nanotech, translated, metasyntactic, flavour, tachycardia, map, shunning,
# Nearest to for: without, of, through, kildare, with, by, astonishing, deception,
# Nearest to in: at, on, during, from, of, under, between, with,
# Nearest to between: with, against, from, in, airspeed, nicolay, pregnancy, belo,
# Nearest to two: four, three, six, five, one, seven, eight, zero,
# Nearest to history: unsure, polytheism, fes, nipples, transl, lotta, debacle, culture,
# Average loss at step 32000: 3.502893
# Average loss at step 34000: 3.494751
# Average loss at step 36000: 3.455762
# Average loss at step 38000: 3.300672
# Average loss at step 40000: 3.427025
# Nearest to s: his, des, her, williams, cookie, communications, sympathizer, lexemes,
# Nearest to called: prosciutto, vaguely, exploits, excitement, used, incorporation, saboteurs, kibo,
# Nearest to seven: five, eight, six, nine, three, four, zero, two,
# Nearest to it: he, there, she, they, this, actually, fournier, chmielnicki,
# Nearest to such: well, known, these, many, linguistique, some, described, replicants,
# Nearest to but: however, although, and, though, while, before, are, when,
# Nearest to after: before, during, when, while, was, ecole, ascended, from,
# Nearest to while: when, although, but, however, were, before, and, are,
# Nearest to many: some, several, these, various, those, both, such, all,
# Nearest to this: which, it, the, that, what, he, clapping, there,
# Nearest to an: wakshul, translated, metasyntactic, dougal, nanotech, diatessaron, flavour, climatic,
# Nearest to for: in, by, of, and, after, suprema, ibu, munro,
# Nearest to in: during, from, for, and, on, of, with, munster,
# Nearest to between: against, nicolay, with, among, figured, within, airspeed, sightseeing,
# Nearest to two: three, four, six, five, seven, eight, zero, nine,
# Nearest to history: polytheism, democratisation, fes, unsure, journal, nipples, disuse, kinds,
# Average loss at step 42000: 3.443441
# Average loss at step 44000: 3.454242
# Average loss at step 46000: 3.450864
# Average loss at step 48000: 3.353469
# Average loss at step 50000: 3.387663
# Nearest to s: des, and, his, socioeconomic, although, isbn, whose, governance,
# Nearest to called: saboteurs, prosciutto, vaguely, excitement, used, titled, named, exploits,
# Nearest to seven: eight, six, nine, four, three, five, zero, two,
# Nearest to it: he, she, there, this, they, actually, fournier, chmielnicki,
# Nearest to such: well, these, known, many, linguistique, described, replicants, ropes,
# Nearest to but: however, although, while, and, though, when, where, which,
# Nearest to after: before, when, while, during, ecole, blitz, without, by,
# Nearest to while: although, when, however, but, after, where, before, though,
# Nearest to many: some, several, these, various, both, such, most, those,
# Nearest to this: which, it, the, some, he, there, clapping, that,
# Nearest to an: wakshul, nanotech, the, browser, procellariiformes, flavour, metasyntactic, no,
# Nearest to for: without, including, by, while, eritrean, although, chevalier, from,
# Nearest to in: of, during, from, within, on, peking, and, since,
# Nearest to between: against, with, among, from, within, nicolay, figured, airspeed,
# Nearest to two: three, four, six, one, eight, five, seven, zero,
# Nearest to history: democratisation, polytheism, journal, unsure, fes, oddity, fokker, province,
# Average loss at step 52000: 3.436724
# Average loss at step 54000: 3.426473
# Average loss at step 56000: 3.441368
# Average loss at step 58000: 3.398309
# Average loss at step 60000: 3.392684
# Nearest to s: whose, sank, isbn, residency, routers, stacking, barred, lexemes,
# Nearest to called: used, excitement, saboteurs, vaguely, ligase, prosciutto, required, satirised,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to it: he, she, there, this, what, which, they, never,
# Nearest to such: known, well, these, many, described, steamship, replicants, including,
# Nearest to but: however, although, and, though, while, when, than, see,
# Nearest to after: before, during, when, while, without, although, upon, despite,
# Nearest to while: although, when, after, before, but, however, without, were,
# Nearest to many: some, several, these, various, both, other, most, all,
# Nearest to this: it, which, the, there, that, some, what, another,
# Nearest to an: metasyntactic, wakshul, nanotech, clem, marijuana, browser, unselfish, aubrey,
# Nearest to for: of, including, overboard, without, when, optical, kildare, deception,
# Nearest to in: during, within, of, from, throughout, among, peking, until,
# Nearest to between: with, among, against, within, commented, around, figured, nicolay,
# Nearest to two: three, four, five, seven, six, eight, one, zero,
# Nearest to history: journal, economy, democratisation, nipples, list, culture, polytheism, lotta,
# Average loss at step 62000: 3.241427
# Average loss at step 64000: 3.252887
# Average loss at step 66000: 3.408746
# Average loss at step 68000: 3.395684
# Average loss at step 70000: 3.359631
# Nearest to s: whose, des, socioeconomic, barred, must, evangelium, hq, corporatist,
# Nearest to called: saboteurs, excitement, used, vaguely, known, bowled, exported, attractiveness,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Nearest to it: he, she, there, this, they, fournier, also, never,
# Nearest to such: these, known, well, certain, many, steamship, replicants, some,
# Nearest to but: however, although, though, that, and, while, see, which,
# Nearest to after: before, during, when, while, without, sophist, for, nozzle,
# Nearest to while: although, however, and, when, before, though, after, including,
# Nearest to many: some, several, various, these, all, most, numerous, other,
# Nearest to this: which, it, the, some, that, another, there, what,
# Nearest to an: metasyntactic, wakshul, shunning, myrrh, nanotech, translated, openly, detriment,
# Nearest to for: to, including, after, if, in, picasso, of, amon,
# Nearest to in: within, during, on, throughout, through, until, from, of,
# Nearest to between: with, within, among, around, in, against, sightseeing, from,
# Nearest to two: three, four, six, five, seven, one, eight, zero,
# Nearest to history: journal, list, democratisation, culture, period, outputting, debacle, disuse,
# Average loss at step 72000: 3.374300
# Average loss at step 74000: 3.349700
# Average loss at step 76000: 3.319413
# Average loss at step 78000: 3.353716
# Average loss at step 80000: 3.382205
# Nearest to s: isbn, des, charlton, wildly, surreal, gelatin, agha, pediatrician,
# Nearest to called: used, saboteurs, known, vaguely, attractiveness, named, excitement, prosciutto,
# Nearest to seven: five, eight, six, four, nine, three, zero, one,
# Nearest to it: he, she, there, this, they, never, we, still,
# Nearest to such: these, well, known, certain, defined, groucho, steamship, many,
# Nearest to but: however, although, though, which, while, see, and, when,
# Nearest to after: before, during, while, when, without, despite, sophist, from,
# Nearest to while: although, after, however, though, before, when, including, but,
# Nearest to many: some, several, various, these, numerous, all, most, few,
# Nearest to this: it, which, the, what, that, some, he, there,
# Nearest to an: metasyntactic, nanotech, wakshul, browser, muhammed, translated, openly, wabash,
# Nearest to for: webmineral, eritrean, ursidae, amounting, picasso, scissors, gallia, after,
# Nearest to in: during, until, on, throughout, within, at, riverboat, since,
# Nearest to between: within, among, with, around, against, nicolay, from, belo,
# Nearest to two: three, six, four, five, seven, one, eight, zero,
# Nearest to history: journal, list, democratisation, title, iscariot, kinds, origins, pointless,
# Average loss at step 82000: 3.411351
# Average loss at step 84000: 3.408900
# Average loss at step 86000: 3.391458
# Average loss at step 88000: 3.356598
# Average loss at step 90000: 3.364922
# Nearest to s: whose, isbn, des, barred, gelatin, his, residency, corporatist,
# Nearest to called: saboteurs, attractiveness, used, known, prosciutto, named, vaguely, jens,
# Nearest to seven: eight, five, nine, four, six, three, zero, two,
# Nearest to it: he, she, there, this, they, itself, never, actually,
# Nearest to such: known, well, these, certain, defined, groucho, described, steamship,
# Nearest to but: however, and, although, though, while, they, nor, which,
# Nearest to after: before, during, when, while, without, despite, until, from,
# Nearest to while: although, when, though, after, before, were, during, but,
# Nearest to many: several, some, numerous, these, various, few, all, most,
# Nearest to this: it, which, some, another, lfflin, the, he, itself,
# Nearest to an: nanotech, metasyntactic, wakshul, clem, landmines, diatessaron, dues, wabash,
# Nearest to for: including, of, after, without, when, webmineral, if, sputnik,
# Nearest to in: during, within, under, atlanteans, peking, throughout, until, minimalistic,
# Nearest to between: with, within, among, against, in, around, belo, nicolay,
# Nearest to two: three, four, five, seven, six, eight, one, zero,
# Nearest to history: list, journal, democratisation, iscariot, origins, culture, outputting, kinds,
# Average loss at step 92000: 3.402347
# Average loss at step 94000: 3.258598
# Average loss at step 96000: 3.362326
# Average loss at step 98000: 3.247013
# Average loss at step 100000: 3.357366
# Nearest to s: whose, his, barred, halloween, ruth, accuses, lexemes, isbn,
# Nearest to called: saboteurs, attractiveness, named, vaguely, prosciutto, known, used, referred,
# Nearest to seven: four, eight, six, five, nine, three, zero, two,
# Nearest to it: he, she, there, this, they, never, sie, actually,
# Nearest to such: known, well, these, groucho, defined, many, certain, including,
# Nearest to but: however, and, although, though, which, nor, while, attenuated,
# Nearest to after: before, during, when, without, while, despite, sophist, for,
# Nearest to while: although, when, though, after, before, and, where, roslin,
# Nearest to many: some, several, these, various, numerous, few, all, such,
# Nearest to this: which, it, another, the, dispossessed, lfflin, he, disintegrate,
# Nearest to an: nanotech, metasyntactic, wakshul, clem, diatessaron, platters, optics, alfredo,
# Nearest to for: before, when, after, if, including, webmineral, without, praeger,
# Nearest to in: during, within, throughout, until, at, on, pounder, under,
# Nearest to between: with, within, among, against, nicolay, belo, sightseeing, around,
# Nearest to two: three, four, five, six, seven, eight, one, zero,
# Nearest to history: list, journal, description, scenic, kinds, outputting, justifying, secretory,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
